# %%
import pandas as pd
import numpy as np

# %%
# Loading data
sonar = pd.read_csv(r'C:\test\sonar (1).csv', header = None)
X = sonar.iloc[:, 0:60].values
y = sonar.iloc[:, 60].values

# %%
# Feature Encoding
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
encoder = LabelEncoder()
y = encoder.fit_transform(y)

# %%
# Splitting models
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 32)                1952
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_37 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 3,041
# Trainable params: 3,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Building Model
# Import Libraries
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
# Building Model
model = Sequential()
model.add(Dense(32, activation = 'relu', input_dim = 60, kernel_initializer = 'uniform'))
model.add(Dropout(rate = 0.1))
model.add(Dense(32, activation = 'relu', kernel_initializer = 'uniform'))
model.add(Dropout(rate = 0.1))
model.add(Dense(1, activation = 'sigmoid', kernel_initializer = 'uniform'))

# %%
# Compiling Model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting Model
model.fit(X_train, y_train, batch_size = 10, epochs = 20)
# Out:
# Epoch 1/20
# 166/166 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.6145
# Epoch 2/20
# 166/166 [==============================] - 0s 259us/step - loss: 0.6854 - accuracy: 0.7410
# Epoch 3/20
# 166/166 [==============================] - 0s 368us/step - loss: 0.6628 - accuracy: 0.7229
# Epoch 4/20
# 166/166 [==============================] - 0s 247us/step - loss: 0.6053 - accuracy: 0.7651
# Epoch 5/20
# 166/166 [==============================] - 0s 392us/step - loss: 0.5213 - accuracy: 0.7952
# Epoch 6/20
# 166/166 [==============================] - 0s 332us/step - loss: 0.4451 - accuracy: 0.8072
# Epoch 7/20
# 166/166 [==============================] - 0s 464us/step - loss: 0.3838 - accuracy: 0.8434
# Epoch 8/20
# 166/166 [==============================] - 0s 329us/step - loss: 0.3272 - accuracy: 0.8614
# Epoch 9/20
# 166/166 [==============================] - 0s 313us/step - loss: 0.2898 - accuracy: 0.8494
# Epoch 10/20
# 166/166 [==============================] - 0s 295us/step - loss: 0.2627 - accuracy: 0.8675
# Epoch 11/20
# 166/166 [==============================] - 0s 247us/step - loss: 0.2365 - accuracy: 0.8916
# Epoch 12/20
# 166/166 [==============================] - 0s 271us/step - loss: 0.2148 - accuracy: 0.9096
# Epoch 13/20
# 166/166 [==============================] - 0s 277us/step - loss: 0.1900 - accuracy: 0.9217
# Epoch 14/20
# 166/166 [==============================] - 0s 277us/step - loss: 0.1660 - accuracy: 0.9458
# Epoch 15/20
# 166/166 [==============================] - 0s 265us/step - loss: 0.1435 - accuracy: 0.9578
# Epoch 16/20
# 166/166 [==============================] - 0s 229us/step - loss: 0.1174 - accuracy: 0.9759
# Epoch 17/20
# 166/166 [==============================] - 0s 270us/step - loss: 0.1030 - accuracy: 0.9819
# Epoch 18/20
# 166/166 [==============================] - 0s 229us/step - loss: 0.0867 - accuracy: 0.9940
# Epoch 19/20
# 166/166 [==============================] - 0s 289us/step - loss: 0.0760 - accuracy: 0.9819
# Epoch 20/20
# 166/166 [==============================] - 0s 271us/step - loss: 0.0620 - accuracy: 0.9940

# %%
# Predicting on test set
y_pred = model.predict(X_test) > 0.5

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[20,  1],
#        [ 3, 18]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9047619047619048
